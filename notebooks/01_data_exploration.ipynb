# %%
import sys

print(sys.executable)
# Out:
# c:\STIKSTOF-AI\stikstof-ai\.venv\Scripts\python.exe

# %%
import geopandas as gpd

# %%
natura = gpd.read_file("C:/STIKSTOF-AI/stikstof-ai/data/raw/Natura2000.gpkg")
# Out:
# c:\STIKSTOF-AI\stikstof-ai\.venv\Lib\site-packages\pyogrio\raw.py:200: UserWarning: Measured (M) geometry types are not supported. Original type 'Measured 3D MultiPolygon' is converted to 'MultiPolygon Z'
#   return ogr_read(

# %%
natura.head()
# Out:
#    objectid       naam_n2k  vhn_new   nr beschermin sitecode_v sitecode_h  \
# 0      3852   Coepelduynen        2   96         HR             NL1000030
# 1      3853       De Bruuk        2   69         HR             NL2003011
# 2      3854      De Wieden        1   35         VR  NL3009004
# 3      3855      De Wieden        3   35      VR+HR  NL3009004  NL2003064
# 4      3856  Hollands Diep        3  111      VR+HR  NL9802019  NL2003021
#
#                                               status       kadaster  \
# 0                           Natura 2000-besluit 2010  OZ4 57913/192
# 1                     Natura 2000-besluit 7 mei 2013  OZ4 62860/122
# 2  Natura 2000-besluit 06 jan2014, wijzigingsbesl...  OZ4 63816/126
# 3  Natura 2000-besluit 06 jan2014, wijzigingsbesl...  OZ4 63816/126
# 4               Natura 2000-besluit 4 september 2013  OZ4 63282/152
#
#    staatscour    shape_area      shape_len  \
# 0  2009/19769  1.883720e+06   10956.674179
# 1  2013/12211  9.927285e+05    6988.805471
# 2  2014/00122  1.861693e+07   73385.880390
# 3  2014/00122  7.155826e+07  114233.818450
# 4  2013/19978  5.050132e+06   32739.348710
#
#                                             geometry
# 0  MULTIPOLYGON (((89909.4 472598.9, 89887.48 472...
# 1  MULTIPOLYGON (((194955.346 419781.719, 194946....
# 2  MULTIPOLYGON (((204439.673 522860.604, 204426....
# 3  MULTIPOLYGON (((202944.58 525625.119, 202948.8...
# 4  MULTIPOLYGON (((101304.484 414714.719, 101338....

# %%
natura.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   objectid    209 non-null    int32
#  1   naam_n2k    209 non-null    str
#  2   vhn_new     209 non-null    int16
#  3   nr          209 non-null    int32
#  4   beschermin  209 non-null    str
#  5   sitecode_v  209 non-null    str
#  6   sitecode_h  208 non-null    str
#  7   status      209 non-null    str
#  8   kadaster    209 non-null    str
#  9   staatscour  207 non-null    str
#  10  shape_area  209 non-null    float64
#  11  shape_len   209 non-null    float64
#  12  geometry    209 non-null    geometry
# dtypes: float64(2), geometry(1), int16(1), int32(2), str(7)
# memory usage: 18.5 KB

# %%
natura.crs
# Out:
# <Projected CRS: EPSG:28992>
# Name: Amersfoort / RD New
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Netherlands - onshore, including Waddenzee, Dutch Wadden Islands and 12-mile offshore coastal zone.
# - bounds: (3.2, 50.75, 7.22, 53.7)
# Coordinate Operation:
# - name: RD New
# - method: Oblique Stereographic
# Datum: Amersfoort
# - Ellipsoid: Bessel 1841
# - Prime Meridian: Greenwich

# %%
natura.geometry
# Out:
# 0      MULTIPOLYGON (((89909.4 472598.9, 89887.48 472...
# 1      MULTIPOLYGON (((194955.346 419781.719, 194946....
# 2      MULTIPOLYGON (((204439.673 522860.604, 204426....
# 3      MULTIPOLYGON (((202944.58 525625.119, 202948.8...
# 4      MULTIPOLYGON (((101304.484 414714.719, 101338....
#                              ...
# 204    MULTIPOLYGON (((14400.576 534692.486, 7679.345...
# 205    MULTIPOLYGON (((196740.635 531842.578, 196741....
# 206    MULTIPOLYGON (((253410.883 609862.638, 252639....
# 207    MULTIPOLYGON (((230472.653 604679.634, 230474....
# 208    MULTIPOLYGON (((81906.758 413075.719, 81869.81...
# Name: geometry, Length: 209, dtype: geometry

# %%
import matplotlib.pyplot as plt

# %%
natura.plot(figsize=(10, 10))
plt.title("Natura 2000 areas in the Netherlands")
plt.xlabel("Easting (metres)")
plt.ylabel("Northing (metres)")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
natura.plot(
    ax=ax,
    edgecolor="black",
    facecolor="none"
)
ax.set_title("Natura 2000 Protected Areas - Netherlands")
ax.set_xlabel("Easting (metres)")
ax.set_ylabel("Norting (metres)")
plt.show()

# %%
natura.total_bounds
# Out:
# array([-15520.8606, 307155.1412, 276784.4987, 852886.8113])

# %%
len(natura)
# Out:
# 209

# %%
import geopandas as gpd

# %%
natura = gpd.read_file("../data/raw/Natura2000.gpkg")
# Out:
# c:\STIKSTOF-AI\stikstof-ai\.venv\Lib\site-packages\pyogrio\raw.py:200: UserWarning: Measured (M) geometry types are not supported. Original type 'Measured 3D MultiPolygon' is converted to 'MultiPolygon Z'
#   return ogr_read(

# %%
natura.columns
# Out:
# Index(['objectid', 'naam_n2k', 'vhn_new', 'nr', 'beschermin', 'sitecode_v',
#        'sitecode_h', 'status', 'kadaster', 'staatscour', 'shape_area',
#        'shape_len', 'geometry'],
#       dtype='str')

# %%
natura.head()
# Out:
#    objectid       naam_n2k  vhn_new   nr beschermin sitecode_v sitecode_h  \
# 0      3852   Coepelduynen        2   96         HR             NL1000030
# 1      3853       De Bruuk        2   69         HR             NL2003011
# 2      3854      De Wieden        1   35         VR  NL3009004
# 3      3855      De Wieden        3   35      VR+HR  NL3009004  NL2003064
# 4      3856  Hollands Diep        3  111      VR+HR  NL9802019  NL2003021
#
#                                               status       kadaster  \
# 0                           Natura 2000-besluit 2010  OZ4 57913/192
# 1                     Natura 2000-besluit 7 mei 2013  OZ4 62860/122
# 2  Natura 2000-besluit 06 jan2014, wijzigingsbesl...  OZ4 63816/126
# 3  Natura 2000-besluit 06 jan2014, wijzigingsbesl...  OZ4 63816/126
# 4               Natura 2000-besluit 4 september 2013  OZ4 63282/152
#
#    staatscour    shape_area      shape_len  \
# 0  2009/19769  1.883720e+06   10956.674179
# 1  2013/12211  9.927285e+05    6988.805471
# 2  2014/00122  1.861693e+07   73385.880390
# 3  2014/00122  7.155826e+07  114233.818450
# 4  2013/19978  5.050132e+06   32739.348710
#
#                                             geometry
# 0  MULTIPOLYGON (((89909.4 472598.9, 89887.48 472...
# 1  MULTIPOLYGON (((194955.346 419781.719, 194946....
# 2  MULTIPOLYGON (((204439.673 522860.604, 204426....
# 3  MULTIPOLYGON (((202944.58 525625.119, 202948.8...
# 4  MULTIPOLYGON (((101304.484 414714.719, 101338....

# %%
natura.dtypes
# Out:
# objectid         int32
# naam_n2k           str
# vhn_new          int16
# nr               int32
# beschermin         str
# sitecode_v         str
# sitecode_h         str
# status             str
# kadaster           str
# staatscour         str
# shape_area     float64
# shape_len      float64
# geometry      geometry
# dtype: object

# %%
natura.shape
# Out:
# (209, 13)

# %%
import geopandas as gpd

# %%
natura = gpd.read_file("../data/raw/Natura2000.gpkg")
# Out:
# c:\STIKSTOF-AI\stikstof-ai\.venv\Lib\site-packages\pyogrio\raw.py:200: UserWarning: Measured (M) geometry types are not supported. Original type 'Measured 3D MultiPolygon' is converted to 'MultiPolygon Z'
#   return ogr_read(

# %%
natura["naam_n2k"].nunique()
# Out:
# 162

# %%
natura["nr"].nunique()
# Out:
# 162

# %%
natura["beschermin"].value_counts()
# Out:
# beschermin
# HR           108
# VR+HR         58
# VR            39
# HR groeve      4
# Name: count, dtype: int64

# %%
natura["naam_n2k"].value_counts().head(20)
# Out:
# naam_n2k
# Hollands Diep                                     3
# Brabantse Wal                                     3
# Ilperveld, Varkensland, Oostzanerveld & Twiske    3
# Uiterwaarden Zwarte Water en Vecht                3
# Wormer- en Jisperveld & Kalverpolder              3
# Weerter- en Budelerbergen & Ringselven            3
# De Wieden                                         2
# Bemelerberg & Schiepersberg                       2
# IJsselmeer                                        2
# Biesbosch                                         2
# Maasduinen                                        2
# Savelsbos                                         2
# Voornes Duin                                      2
# Duinen en Lage Land Texel                         2
# Duinen Goeree & Kwade Hoek                        2
# Kampina & Oisterwijkse Vennen                     2
# Geuldal                                           2
# Haringvliet                                       2
# Duinen Terschelling                               2
# Duinen Vlieland                                   2
# Name: count, dtype: int64
